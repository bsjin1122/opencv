# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('../Computer-Vision-with-Python/DATA/rainbow.jpg',0)

# %%
plt.imshow(img, cmap='gray')

# %%
255/2
# Out:
# 127.5

# %%
img.max()
# Out:
# 214

# %%
ret, thresh1 = cv2.threshold(img,127, 255, cv2.THRESH_TRUNC) #혹은 THRESH_BINARY. (THRESH_BINARY_INV INV는 반전된 것)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1, cmap='gray')

# %%
img = cv2.imread('../Computer-Vision-with-Python/DATA/crossword.jpg',0)

# %%
plt.imshow(img, cmap='gray')

# %%
def show_pic(img):
    fig = plt.figure(figsize=(15, 15))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap='gray')

# %%
show_pic(img)

# %%
ret, th1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY) #임계값을 변경해보기, 2) 적응형 이진화: 임계값을 자동으로 픽셀과 그 주변 회색 픽셀에 기반
show_pic(th1)

# %%
th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 8)
show_pic(th2)

# %%
blended = cv2.addWeighted(src1= th1, alpha=0.6, src2=th2, beta=0.4, gamma=0)

# %%
show_pic(blended)
