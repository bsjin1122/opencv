# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('../Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread('wrong/path/doesnot/hkadkja.jpg')

# %%
type(img)
# Out:
# NoneType

# %%
img = cv2.imread('../Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RGB RED GREEN BLUE
# OPENCV ---> BGR   BLUE GREEN RED

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('../Computer-Vision-with-Python/DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
img_gray
# Out:
# array([[85, 87, 88, ..., 26, 26, 26],
#        [85, 86, 86, ..., 26, 26, 26],
#        [85, 84, 84, ..., 26, 26, 26],
#        ...,
#        [25, 26, 26, ..., 27, 28, 28],
#        [26, 26, 25, ..., 27, 28, 28],
#        [26, 25, 25, ..., 27, 28, 28]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 1

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img,(1000, 400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8
h_ratio = 0.2 #20% of original height

# %%
new_img = cv2.resize(fix_img, (0, 0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (260, 1560, 3)

# %%
new_img = cv2.flip(fix_img, -1) #1은 좌우반전, 0은 상하반전, -1 상하좌우
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg', fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize = (8, 10))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
